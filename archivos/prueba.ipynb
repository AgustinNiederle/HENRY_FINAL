# %%
import pandas as pd
business_id = pd.read_csv("../data/data_city_filter/business_filtered.csv")

# %%
business_id.head()
rev_count = business_id[business_id["review_count"]<10]
rev_count.head(20)
# Out:
#                 business_id                               name  \
# 9    xfmkEGiIERBaBMLhw-dTCg           Walmart Vision & Glasses
# 13   -aeZuatjCDMV1X4gCTz9Ug             David Thomas Trailways
# 16   07JLsUInZr5OSiYH2XVi4g     Elegance African Hair Braiding
# 22   D9Xez9uOSM4DgSjSTywq7w                   King of Jewelers
# 23   MyE_zdul_JO-dOHOug4GQQ  Watson Adventures Scavenger Hunts
# 37   yZP6Z8sbDpkeXyjNMDiyDg              Guess - Walnut Street
# 39   V-96iACFgPmVjjKACGxd7Q               Fusion Pizza & Grill
# 49   2M4pYfuivdluXyBOP7IDQw              Look Hair Care Studio
# 50   i_cFU5_dQexbjJA9rmf_WA                      Marcie Blaine
# 51   tUl_Lq8dM3T-NnM-u3szSg                    Damaso Painting
# 59   yUEeh9nwaycI6fKLruD_rQ        Silvio Hair Styling For Men
# 69   yFqq66GxRjnhZXPgjA6hnw                                KFC
# 70   rh3C_JK4NAoUJ-HNStvHtw         Historic Philadelphia, Inc
# 80   HQolH8hSvmK8mhZc0bYVRw             Global Appliance Parts
# ...
